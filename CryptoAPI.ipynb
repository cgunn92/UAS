# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '379170db-41d4-4b40-ba77-95d3dcab5b37',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
import os
from time import time, sleep

# %%
pd.json_normalize(data['status'])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2023-06-14T13:08:50.342Z           0          None       31             1
#
#   notice  total_count
# 0   None        10454

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
#add a timestamp column to keep track of new queries
df['timestamp'] = pd.to_datetime('now', utc=True)
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin             10247
# 1   1027     Ethereum    ETH              ethereum              7001
# 2    825       Tether   USDT                tether             55524
# 3   1839          BNB    BNB                   bnb              1459
# 4   3408     USD Coin   USDC              usd-coin             12974
# 5     52          XRP    XRP                   xrp               965
# 6   2010      Cardano    ADA               cardano               838
# 7     74     Dogecoin   DOGE              dogecoin               728
# 8   1958         TRON    TRX                  tron               772
# 9   5426       Solana    SOL                solana               472
# 10  3890      Polygon  MATIC               polygon               742
# 11     2     Litecoin    LTC              litecoin               924
# 12  6636     Polkadot    DOT          polkadot-new               514
# ...

# %%
def api_runner():
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '379170db-41d4-4b40-ba77-95d3dcab5b37',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now', utc=True)
    
    if not os.path.isfile(r'/Users/calebgunn/repos/UAS'):
        df2.to_csv(r'/Users/calebgunn/repos/UAS/data.csv', header='column_names')
    else:
        df2.to_csv(r'/Users/calebgunn/repos/UAS/data.csv', mode='a', header=False)
    
    return df2

# %%
#setting up a for loop to be able to call the api_runner function repeatedly at specified intervals
for i in range(1):
    df = df.append(api_runner())
    print('Process completed successfully')
    sleep(60)
# Out:
# /var/folders/h4/g3_ffqw91q37kfjl62885hh00000gn/T/ipykernel_6039/1123842581.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(api_runner())
# Process completed successfully

# %%
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin             10247
# 1   1027     Ethereum    ETH              ethereum              7001
# 2    825       Tether   USDT                tether             55524
# 3   1839          BNB    BNB                   bnb              1459
# 4   3408     USD Coin   USDC              usd-coin             12974
# 5     52          XRP    XRP                   xrp               965
# 6   2010      Cardano    ADA               cardano               838
# 7     74     Dogecoin   DOGE              dogecoin               728
# 8   1958         TRON    TRX                  tron               772
# 9   5426       Solana    SOL                solana               472
# 10  3890      Polygon  MATIC               polygon               742
# 11     2     Litecoin    LTC              litecoin               924
# 12  6636     Polkadot    DOT          polkadot-new               514
# ...

# %%
#making all float values more readable
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin             10247
# 1   1027     Ethereum    ETH              ethereum              7001
# 2    825       Tether   USDT                tether             55524
# 3   1839          BNB    BNB                   bnb              1459
# 4   3408     USD Coin   USDC              usd-coin             12974
# 5     52          XRP    XRP                   xrp               965
# 6   2010      Cardano    ADA               cardano               838
# 7     74     Dogecoin   DOGE              dogecoin               728
# 8   1958         TRON    TRX                  tron               772
# 9   5426       Solana    SOL                solana               472
# 10  3890      Polygon  MATIC               polygon               742
# 11     2     Litecoin    LTC              litecoin               924
# 12  6636     Polkadot    DOT          polkadot-new               514
# ...

# %%
#showing the 'average' change in value against the USD for each crypto
df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.11260                      -0.41950
# Ethereum                        -0.08934                       0.08988
# Tether                           0.00133                      -0.01533
# BNB                             -0.11203                       2.49320
# USD Coin                        -0.00533                      -0.01599
# XRP                             -0.47437                      -5.79295
# Cardano                          0.00577                      -2.06327
# Dogecoin                        -0.04293                       0.18193
# TRON                             0.10488                       1.25879
# Solana                           0.05838                      -1.55677
# Polygon                         -0.32557                      -0.41113
# Litecoin                        -0.13524                      -0.72509
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.11260
#              quote.USD.percent_change_24h    -0.41950
#              quote.USD.percent_change_7d     -2.93278
#              quote.USD.percent_change_30d    -5.11274
#              quote.USD.percent_change_60d   -14.62536
#                                                ...
# Binance USD  quote.USD.percent_change_24h    -0.02916
#              quote.USD.percent_change_7d     -0.01373
#              quote.USD.percent_change_30d    -0.05758
#              quote.USD.percent_change_60d    -0.09589
#              quote.USD.percent_change_90d     0.02219
# Length: 90, dtype: float64
