# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '379170db-41d4-4b40-ba77-95d3dcab5b37',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
pd.json_normalize(data['status'])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2023-06-12T14:25:36.016Z           0          None       67            25
#
#   notice  total_count
# 0   None        10429

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now', utc=True)
df
# Out:
#          id              name   symbol            slug  num_market_pairs  \
# 0         1           Bitcoin      BTC         bitcoin             10245
# 1      1027          Ethereum      ETH        ethereum              6997
# 2       825            Tether     USDT          tether             55415
# 3      1839               BNB      BNB             bnb              1456
# 4      3408          USD Coin     USDC        usd-coin             12953
# ...     ...               ...      ...             ...               ...
# 4995  18795           KOMPETE  KOMPETE         kompete                 5
# 4996  16742    Monster Galaxy      GGM  monster-galaxy                 2
# 4997   6742    DxSale.Network     SALE  dxsale-network                10
# 4998  17698  Lucky Block (V1)   LBLOCK     lucky-block                13
# 4999  23481        GlieseCoin      GLC      gliesecoin                 3
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2017-07-25T00:00:00.000Z
# 4     2018-10-08T00:00:00.000Z
# ...                        ...
# 4995  2022-03-14T12:43:58.000Z
# 4996  2022-01-03T04:00:52.000Z
# 4997  2020-08-28T00:00:00.000Z
# 4998  2022-01-28T03:51:28.000Z
# 4999  2023-02-12T18:08:19.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [marketplace, centralized-exchange, payments, ...           NaN
# 4     [medium-of-exchange, stablecoin, asset-backed-...           NaN
# ...                                                 ...           ...
# 4995                                           [gaming]  1.000000e+09
# 4996  [collectibles-nfts, gaming, play-to-earn, bnb-...           NaN
# 4997        [launchpad, avalanche-ecosystem, bnb-chain]  8.968349e+07
# 4998                                                 []  1.000000e+11
# 4999                                                 []  2.050000e+07
#
#       circulating_supply        total_supply  infinite_supply  platform  \
# 0           1.940027e+07            19400268            False       NaN
# 1           1.202269e+08    120226893.330775             True       NaN
# 2           8.336651e+10  86083529362.369095             True       NaN
# 3           1.558544e+08    155854437.755412            False       NaN
# 4           2.839482e+10  28394820689.189983            False       NaN
# ...                  ...                 ...              ...       ...
# 4995        0.000000e+00                   0            False       NaN
# 4996        0.000000e+00                   0            False       NaN
# 4997        0.000000e+00            44745171            False       NaN
# 4998        0.000000e+00  99600521807.679993            False       NaN
# 4999        0.000000e+00            20500000            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4996                               NaN                       NaN
# 4996      4997                               NaN                       NaN
# 4997      4998                               NaN                       NaN
# 4998      4999                      4.077324e+10             531979.947114
# 4999      5001                      4.950340e+06              42538.968492
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2023-06-12T14:23:00.000Z     25830.896712
# 1           NaN  2023-06-12T14:23:00.000Z      1740.504136
# 2           NaN  2023-06-12T14:23:00.000Z         1.000066
# 3           NaN  2023-06-12T14:23:00.000Z       231.906456
# 4           NaN  2023-06-12T14:23:00.000Z         0.999947
# ...         ...                       ...              ...
# 4995        NaN  2023-06-12T14:23:00.000Z         0.009406
# 4996        NaN  2023-06-12T14:23:00.000Z         0.003707
# 4997        NaN  2023-06-12T14:23:00.000Z         0.089727
# 4998        NaN  2023-06-12T14:23:00.000Z         0.000013
# 4999        NaN  2023-06-12T14:23:00.000Z         0.008593
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             1.263642e+10                       0.4132
# 1             5.902501e+09                       6.9679
# 2             2.123452e+10                       0.8855
# 3             9.125133e+08                      97.7879
# 4             3.194880e+09                       6.5363
# ...                    ...                          ...
# 4995          8.866163e+03                      -1.0639
# 4996          8.832635e+03                     -15.2270
# 4997          8.782551e+03                     -57.1431
# 4998          8.771789e+03                     -67.3729
# 4999          8.762471e+03                     -88.9249
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                       -0.189038                      0.242416
# 1                       -0.206612                     -0.349068
# 2                        0.004038                     -0.033558
# 3                        0.239363                     -1.530373
# 4                        0.019261                     -0.003763
# ...                           ...                           ...
# 4995                    -0.168225                     -0.527788
# 4996                    -1.867015                     -0.785590
# 4997                     0.198282                     -0.787973
# 4998                     0.497494                      1.342742
# 4999                    -0.825361                     -3.292283
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       -3.511599                     -3.659209
# 1                       -6.820645                     -3.275268
# 2                       -0.012963                     -0.048635
# 3                      -22.648196                    -25.199332
# 4                       -0.007449                     -0.011262
# ...                           ...                           ...
# 4995                   -18.035624                      4.870226
# 4996                   -15.217740                    -28.817090
# 4997                   -23.477693                    -29.005066
# 4998                    -8.365692                    -60.609801
# 4999                   -21.438090                    -50.206755
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                       -14.627103                     -0.223569
# 1                       -12.849098                     -0.049430
# 2                        -0.084900                     -0.237986
# 3                       -28.222479                    -26.872590
# 4                         0.007224                      0.221149
# ...                            ...                           ...
# 4995                    -56.065108                    -57.056147
# 4996                    -39.959210                    -28.128192
# 4997                    -47.608073                    -48.699187
# 4998                    -86.342893                    -86.242478
# 4999                    -82.025671                    -79.697016
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             5.011263e+11                         47.6293
# 1             2.092554e+11                         19.8885
# 2             8.337201e+10                          7.9248
# 3             3.614365e+10                          3.4356
# 4             2.839332e+10                          2.6989
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           5.424488e+11            NaN
# 1                           2.092554e+11            NaN
# 2                           8.608921e+10            NaN
# 3                           3.614365e+10            NaN
# 4                           2.839332e+10            NaN
# ...                                  ...            ...
# 4995                        9.405986e+06            NaN
# 4996                        0.000000e+00            NaN
# 4997                        8.047038e+06            NaN
# 4998                        1.304728e+06            NaN
# 4999                        1.761594e+05            NaN
#
#         quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0     2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 1     2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 2     2023-06-12T14:23:00.000Z       1027.0      Ethereum             ETH
# 3     2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 4     2023-06-12T14:23:00.000Z       1027.0      Ethereum             ETH
# ...                        ...          ...           ...             ...
# 4995  2023-06-12T14:23:00.000Z       1027.0      Ethereum             ETH
# 4996  2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 4997  2023-06-12T14:23:00.000Z       1027.0      Ethereum             ETH
# 4998  2023-06-12T14:23:00.000Z       1839.0           BNB             BNB
# 4999  2023-06-12T14:23:00.000Z       1839.0           BNB             BNB
#
#      platform.slug                      platform.token_address  \
# 0              NaN                                         NaN
# 1              NaN                                         NaN
# 2         ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN                                         NaN
# 4         ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ...            ...                                         ...
# 4995      ethereum  0x1E0b2992079B620AA13A7c2E7c88D2e1E18E46E9
# 4996           NaN                                         NaN
# 4997      ethereum  0xF063fE1aB7a291c5d06a86e14730b00BF24cB589
# 4998           bnb  0x2cD96e8C3FF6b5E01169F6E3b61D28204E7810Bb
# 4999           bnb  0xcc780503E290274CFa8Da085528067E259DF58f0
#
#                             timestamp
# 0    2023-06-12 14:25:53.598798+00:00
# 1    2023-06-12 14:25:53.598798+00:00
# 2    2023-06-12 14:25:53.598798+00:00
# 3    2023-06-12 14:25:53.598798+00:00
# 4    2023-06-12 14:25:53.598798+00:00
# ...                               ...
# 4995 2023-06-12 14:25:53.598798+00:00
# 4996 2023-06-12 14:25:53.598798+00:00
# 4997 2023-06-12 14:25:53.598798+00:00
# 4998 2023-06-12 14:25:53.598798+00:00
# 4999 2023-06-12 14:25:53.598798+00:00
#
# [5000 rows x 37 columns]

# %%
def api_runner():
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '379170db-41d4-4b40-ba77-95d3dcab5b37',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now', utc=True)
    return df2

# %%
import os
from time import time, sleep

for i in range(1):
    df = df.append(api_runner())
    print('Process completed successfully')
    sleep(60)
# Out:
# /var/folders/h4/g3_ffqw91q37kfjl62885hh00000gn/T/ipykernel_20515/2843746916.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(api_runner())
# Process completed successfully

# %%
df
# Out:
#          id                             name   symbol  \
# 0         1                          Bitcoin      BTC
# 1      1027                         Ethereum      ETH
# 2       825                           Tether     USDT
# 3      1839                              BNB      BNB
# 4      3408                         USD Coin     USDC
# ...     ...                              ...      ...
# 4995  18795                          KOMPETE  KOMPETE
# 4996  16742                   Monster Galaxy      GGM
# 4997   6742                   DxSale.Network     SALE
# 4998   8056  UNION Protocol Governance Token      UNN
# 4999  23481                       GlieseCoin      GLC
#
#                                  slug  num_market_pairs  \
# 0                             bitcoin             10245
# 1                            ethereum              6997
# 2                              tether             55415
# 3                                 bnb              1456
# 4                            usd-coin             12953
# ...                               ...               ...
# 4995                          kompete                 5
# 4996                   monster-galaxy                 2
# 4997                   dxsale-network                10
# 4998  union-protocol-governance-token                13
# 4999                       gliesecoin                 3
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2017-07-25T00:00:00.000Z
# 4     2018-10-08T00:00:00.000Z
# ...                        ...
# 4995  2022-03-14T12:43:58.000Z
# 4996  2022-01-03T04:00:52.000Z
# 4997  2020-08-28T00:00:00.000Z
# 4998  2020-12-19T00:00:00.000Z
# 4999  2023-02-12T18:08:19.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [marketplace, centralized-exchange, payments, ...           NaN
# 4     [medium-of-exchange, stablecoin, asset-backed-...           NaN
# ...                                                 ...           ...
# 4995                                           [gaming]  1.000000e+09
# 4996  [collectibles-nfts, gaming, play-to-earn, bnb-...           NaN
# 4997        [launchpad, avalanche-ecosystem, bnb-chain]  8.968349e+07
# 4998  [insurance, avalanche-ecosystem, exnetwork-cap...           NaN
# 4999                                                 []  2.050000e+07
#
#       circulating_supply        total_supply  infinite_supply  platform  \
# 0           1.940027e+07            19400268            False       NaN
# 1           1.202269e+08    120226893.330775             True       NaN
# 2           8.336651e+10  86083529362.369095             True       NaN
# 3           1.558544e+08    155854437.755412            False       NaN
# 4           2.839482e+10  28394820689.189983            False       NaN
# ...                  ...                 ...              ...       ...
# 4995        0.000000e+00                   0            False       NaN
# 4996        0.000000e+00                   0            False       NaN
# 4997        0.000000e+00            44745171            False       NaN
# 4998        0.000000e+00          1000000000            False       NaN
# 4999        0.000000e+00            20500000            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4996                               NaN                       NaN
# 4996      4997                               NaN                       NaN
# 4997      4998                               NaN                       NaN
# 4998      4999                       615060532.0             216401.534822
# 4999      5000                         4950340.0              42547.844171
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2023-06-12T14:23:00.000Z     25830.896712
# 1           NaN  2023-06-12T14:23:00.000Z      1740.504136
# 2           NaN  2023-06-12T14:23:00.000Z         1.000066
# 3           NaN  2023-06-12T14:23:00.000Z       231.906456
# 4           NaN  2023-06-12T14:23:00.000Z         0.999947
# ...         ...                       ...              ...
# 4995        NaN  2023-06-12T14:27:00.000Z         0.009403
# 4996        NaN  2023-06-12T14:27:00.000Z         0.003712
# 4997        NaN  2023-06-12T14:27:00.000Z         0.089725
# 4998        NaN  2023-06-12T14:27:00.000Z         0.000352
# 4999        NaN  2023-06-12T14:27:00.000Z         0.008595
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             1.263642e+10                       0.4132
# 1             5.902501e+09                       6.9679
# 2             2.123452e+10                       0.8855
# 3             9.125133e+08                      97.7879
# 4             3.194880e+09                       6.5363
# ...                    ...                          ...
# 4995          8.866163e+03                      -1.0639
# 4996          8.831552e+03                     -15.2248
# 4997          8.782551e+03                     -57.1431
# 4998          8.772921e+03                      -0.8256
# 4999          8.762471e+03                     -88.9249
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                       -0.189038                      0.242416
# 1                       -0.206612                     -0.349068
# 2                        0.004038                     -0.033558
# 3                        0.239363                     -1.530373
# 4                        0.019261                     -0.003763
# ...                           ...                           ...
# 4995                    -0.072829                     -0.495376
# 4996                    -1.910595                     -0.803099
# 4997                     0.420649                     -0.703050
# 4998                    -0.771507                     -4.254356
# 4999                     0.336485                     -3.170421
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       -3.511599                     -3.659209
# 1                       -6.820645                     -3.275268
# 2                       -0.012963                     -0.048635
# 3                      -22.648196                    -25.199332
# 4                       -0.007449                     -0.011262
# ...                           ...                           ...
# 4995                   -18.096834                      4.933348
# 4996                   -15.091517                    -28.723832
# 4997                   -23.479253                    -29.020963
# 4998                   -12.134058                    -27.261121
# 4999                   -21.428720                    -50.206503
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                       -14.627103                     -0.223569
# 1                       -12.849098                     -0.049430
# 2                        -0.084900                     -0.237986
# 3                       -28.222479                    -26.872590
# 4                         0.007224                      0.221149
# ...                            ...                           ...
# 4995                    -56.041890                    -57.148883
# 4996                    -39.801129                    -28.098892
# 4997                    -47.598894                    -48.705431
# 4998                    -42.634769                    -20.872568
# 4999                    -82.023954                    -79.721349
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             5.011263e+11                         47.6293
# 1             2.092554e+11                         19.8885
# 2             8.337201e+10                          7.9248
# 3             3.614365e+10                          3.4356
# 4             2.839332e+10                          2.6989
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           5.424488e+11            NaN
# 1                           2.092554e+11            NaN
# 2                           8.608921e+10            NaN
# 3                           3.614365e+10            NaN
# 4                           2.839332e+10            NaN
# ...                                  ...            ...
# 4995                        9.402787e+06            NaN
# 4996                        0.000000e+00            NaN
# 4997                        8.046874e+06            NaN
# 4998                        3.518378e+05            NaN
# 4999                        1.761961e+05            NaN
#
#         quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0     2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 1     2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 2     2023-06-12T14:23:00.000Z       1027.0      Ethereum             ETH
# 3     2023-06-12T14:23:00.000Z          NaN           NaN             NaN
# 4     2023-06-12T14:23:00.000Z       1027.0      Ethereum             ETH
# ...                        ...          ...           ...             ...
# 4995  2023-06-12T14:27:00.000Z       1027.0      Ethereum             ETH
# 4996  2023-06-12T14:27:00.000Z          NaN           NaN             NaN
# 4997  2023-06-12T14:27:00.000Z       1027.0      Ethereum             ETH
# 4998  2023-06-12T14:27:00.000Z       1027.0      Ethereum             ETH
# 4999  2023-06-12T14:27:00.000Z       1839.0           BNB             BNB
#
#      platform.slug                      platform.token_address  \
# 0              NaN                                         NaN
# 1              NaN                                         NaN
# 2         ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN                                         NaN
# 4         ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ...            ...                                         ...
# 4995      ethereum  0x1E0b2992079B620AA13A7c2E7c88D2e1E18E46E9
# 4996           NaN                                         NaN
# 4997      ethereum  0xF063fE1aB7a291c5d06a86e14730b00BF24cB589
# 4998      ethereum  0x226f7b842e0f0120b7e194d05432b3fd14773a9d
# 4999           bnb  0xcc780503E290274CFa8Da085528067E259DF58f0
#
#                             timestamp
# 0    2023-06-12 14:25:53.598798+00:00
# 1    2023-06-12 14:25:53.598798+00:00
# 2    2023-06-12 14:25:53.598798+00:00
# 3    2023-06-12 14:25:53.598798+00:00
# 4    2023-06-12 14:25:53.598798+00:00
# ...                               ...
# 4995 2023-06-12 14:29:17.683309+00:00
# 4996 2023-06-12 14:29:17.683309+00:00
# 4997 2023-06-12 14:29:17.683309+00:00
# 4998 2023-06-12 14:29:17.683309+00:00
# 4999 2023-06-12 14:29:17.683309+00:00
#
# [10000 rows x 37 columns]
